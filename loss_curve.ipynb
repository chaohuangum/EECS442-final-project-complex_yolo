# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import skl

# %%
# epochs = range(51)
epoches = range(26)

# %%
training_losses = np.array([1934.04, 1899.30, 1881.43, 1891.76, 1852.04, 1845.66, 1828.15, 1815.24, 
                            1766.47, 1784.73, 1779.59, 1750.73, 1750.73, 1753.98, 1759.32, 1739.97, 1755.95, 
                            1716.46, 1727.93, 1724.03, 1741.82, 1727.73, 1724.66, 1704.63, 1700.13, 1716.57,
                           ])

# %%
plt.figure(figsize=(10,6))
plt.plot(epoches, training_losses, '-o', label='Training loss')
plt.legend()
plt.title('Learning curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.xticks(epoches)
plt.savefig('ttt.png')
plt.show()
